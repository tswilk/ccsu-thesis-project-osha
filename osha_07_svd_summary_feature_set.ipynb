# %% [markdown]
# Import the single project module used throughout the analysis. Import Pandas.

# %%
import pandas as pd
import osha_project as osha

# %% [markdown]
# Load the preprocessed text CSV file into Pandas DataFrame and create a new data frame with cleaned summary text only.

# %%
df_txt = pd.read_csv(osha.project_dir + 'df_txt.csv', index_col='summary_nr')
df_summ = df_txt[['partition','fatality_ind','summary_txt_clean']]

# %% [markdown]
# Retrieve parameters used to contruct the 4 vectorized document-term matrices.

# %%
vects = osha.get_summary_vectorizer_info()
for v in vects:
    print v
# Out:
# ['Summary - Stem - Ngrams 1 Only', 'summ_stem_n1', 20, (1, 1), 'stem']
# ['Summary - Stem - Ngrams 1,2,3', 'summ_stem_n123', 20, (1, 3), 'stem']
# ['Summary - Lemma - Ngrams 1 Only', 'summ_lem_n1', 20, (1, 1), 'lemma']
# ['Summary - Lemma - Ngrams 1,2,3', 'summ_lem_n123', 20, (1, 3), 'lemma']

# %% [markdown]
# Generate the 4 vectorized document-term matrices, fit SVD model to train partition data, transform all data and create data frames for modeling.

# %%
svd_dict={}
for v in vects:
    vectorizer_train = osha.get_vectorizer(v[2],v[3],v[4]).fit(osha.get_partition(df_summ,'train').summary_txt_clean)
    vectorized_train = vectorizer_train.transform(osha.get_partition(df_summ,'train').summary_txt_clean)
    normed_vectorizer_train = osha.Normalizer(copy=False).fit(vectorized_train)
    normed_vectorized_train = normed_vectorizer_train.transform(vectorized_train)
    svd_train = osha.TruncatedSVD(n_components = 50).fit(normed_vectorized_train)
    vectorized_all = vectorizer_train.transform(df_summ.summary_txt_clean)
    normed_vectorized_all = normed_vectorizer_train.transform(vectorized_all)
    svd_all = svd_train.transform(normed_vectorized_all)
    df_svd = pd.DataFrame(svd_all, index=df_summ.index, columns=['SVD_Comp_' + str(x+1) for x in range(50)])
    df = df_summ[['partition','fatality_ind']].join(df_svd)
    v.extend([df])
    svd_dict[v[1]] = df
    df.to_csv(osha.svd_summary_dir + 'df_' + v[1] + '.csv', index=True)
    print v[1], vectorized_train.shape
# Out:
# summ_stem_n1 (21331, 2910)
# summ_stem_n123
#  (21331, 7882)
# summ_lem_n1
#  (21331, 3612)
# summ_lem_n123
#  (21331, 8200)

# %% [markdown]
# Plot SVD component scatterplots for top 4 components.

# %%
for v in vects:
    osha.plot_svd_concepts(v[5],'train',v[0], osha.svd_summary_dir, save=True)
    osha.plot_svd_concepts(v[5],'test',v[0], osha.svd_summary_dir, save=True)

# %% [markdown]
# Examine classifiers and default parameter settings.

# %%
clfs = osha.get_classifiers()
clfs
# Out:
# {'AdaBst': AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=1, max_features=None, min_density=None,
#             min_samples_leaf=1, min_samples_split=2, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None),
#  'DTree': DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, min_density=None,
#             min_samples_leaf=1, min_samples_split=2, random_state=None,
#             splitter='best'),
#  'KNN': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=5, p=2, weights='uniform'),
#  'LogReg': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001),
#  'RanFst': RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0)}

# %% [markdown]
# Set Summary SVD feature set variables.

# %%
fs_dir = osha.svd_summary_dir

# %% [markdown]
# Train classification models and log results and metrics for subsequent analysis.

# %%
osha.process_model_batch(svd_dict, clfs, osha.svd_summary_dir)
# Out:
# summ_stem_n1 begin: 2013-11-18 23:09:30
# .....RanFst begin: 2013-11-18 23:09:30
# .....RanFst end: 2013-11-18 23:09:33
# .....AdaBst begin: 2013-11-18 23:09:33
# .....AdaBst end: 2013-11-18 23:09:52
# .....KNN begin: 2013-11-18 23:09:52
# .....KNN end: 2013-11-18 23:15:05
# .....LogReg begin: 2013-11-18 23:15:05
# .....LogReg end: 2013-11-18 23:15:05
# .....DTree begin: 2013-11-18 23:15:05
# .....DTree end: 2013-11-18 23:15:08
# summ_stem_n1 end: 2013-11-18 23:15:08
#
# summ_lem_n123 begin: 2013-11-18 23:15:08
# .....RanFst begin: 2013-11-18 23:15:08
# .....RanFst end: 2013-11-18 23:15:11
# .....AdaBst begin: 2013-11-18 23:15:11
# .....AdaBst end: 2013-11-18 23:15:30
# .....KNN begin: 2013-11-18 23:15:30
# .....KNN end: 2013-11-18 23:20:32
# .....LogReg begin: 2013-11-18 23:20:32
# .....LogReg end: 2013-11-18 23:20:32
# .....DTree begin: 2013-11-18 23:20:32
# .....DTree end: 2013-11-18 23:20:35
# summ_lem_n123 end: 2013-11-18 23:20:35
#
# summ_lem_n1 begin: 2013-11-18 23:20:35
# .....RanFst begin: 2013-11-18 23:20:36
# .....RanFst end: 2013-11-18 23:20:39
# .....AdaBst begin: 2013-11-18 23:20:39
# .....AdaBst end: 2013-11-18 23:20:57
# .....KNN begin: 2013-11-18 23:20:57
# .....KNN end: 2013-11-18 23:25:46
# .....LogReg begin: 2013-11-18 23:25:46
# .....LogReg end: 2013-11-18 23:25:46
# .....DTree begin: 2013-11-18 23:25:46
# .....DTree end: 2013-11-18 23:25:49
# summ_lem_n1 end: 2013-11-18 23:25:49
#
# summ_stem_n123 begin: 2013-11-18 23:25:49
# .....RanFst begin: 2013-11-18 23:25:49
# .....RanFst end: 2013-11-18 23:25:52
# .....AdaBst begin: 2013-11-18 23:25:52
# .....AdaBst end: 2013-11-18 23:26:11
# .....KNN begin: 2013-11-18 23:26:11
# .....KNN end: 2013-11-18 23:31:22
# .....LogReg begin: 2013-11-18 23:31:22
# .....LogReg end: 2013-11-18 23:31:22
# .....DTree begin: 2013-11-18 23:31:22
# .....DTree end: 2013-11-18 23:31:25
# summ_stem_n123 end: 2013-11-18 23:31:25

# %% [markdown]
# Load logged results and metrics data of the best Structured classification model for comparison (Logistic Regression base model).

# %%
df_results_struct = osha.pickle.load(open(osha.structured_dir + 'df_results.p','rb'))
df_results_struct = df_results_struct[df_results_struct.pair_name=='Structured - LogReg']
df_metrics_struct = osha.pickle.load(open(osha.structured_dir + 'df_metrics.p','rb'))
df_metrics_struct = df_metrics_struct[df_metrics_struct.pair_name=='Structured - LogReg']

# %% [markdown]
# Load trained base classification model results, compute combination model results and extend results in preparation for subsequent analyses.

# %%
df_results, df_metrics, col_dict, model_dict, fsets, clfs = osha.get_model_training_info(fs_dir)
df_mrp_results = osha.get_mrp_results(df_results)
df_voting_results = osha.get_voting_results(df_results, len(clfs))
df_mrp_metrics = osha.get_combination_metrics(df_mrp_results)
df_voting_metrics = osha.get_combination_metrics(df_voting_results)
df_results = df_results.append(df_results_struct)
df_metrics = df_metrics.append(df_metrics_struct)
df_all_results = df_results.append(df_mrp_results).append(df_voting_results)
df_all_metrics = df_metrics.append(df_mrp_metrics).append(df_voting_metrics)
df_all_results['target_hit'] = 1 - abs(df_all_results.target_ind - df_all_results.target_pred)
outcome_nbr_map = {'TP':-2 ,'FN':-1, 'FP':1, 'TN':2}
df_all_results['outcome'] = df_all_results[['target_ind','target_pred']].apply(osha.get_outcome,axis=1)
df_all_results['outcome_nbr'] = df_all_results['outcome'].map(outcome_nbr_map)
df_all_results['model_type'] = df_all_results['model_name'].apply(lambda x: osha.get_model_type(x))
df_all_metrics['model_type'] = df_all_metrics['model_name'].apply(lambda x: osha.get_model_type(x))

# %% [markdown]
# Display base model only results ranked by accuracy score, high to low.

# %%
df_metrics.sort('accuracy_score',ascending=False)
# Out:
#                   pair_name       fset_name model_name   duration  \
# 3       Structured - LogReg      Structured     LogReg   0.248161
# 18  summ_stem_n123 - LogReg  summ_stem_n123     LogReg   0.225784
# 3     summ_stem_n1 - LogReg    summ_stem_n1     LogReg   0.234482
# 13     summ_lem_n1 - LogReg     summ_lem_n1     LogReg   0.226267
# 8    summ_lem_n123 - LogReg   summ_lem_n123     LogReg   0.218518
# 16  summ_stem_n123 - AdaBst  summ_stem_n123     AdaBst  17.541474
# 1     summ_stem_n1 - AdaBst    summ_stem_n1     AdaBst  17.667757
# 6    summ_lem_n123 - AdaBst   summ_lem_n123     AdaBst  17.612633
# 11     summ_lem_n1 - AdaBst     summ_lem_n1     AdaBst  17.499945
# 15  summ_stem_n123 - RanFst  summ_stem_n123     RanFst   2.285203
# 0     summ_stem_n1 - RanFst    summ_stem_n1     RanFst   2.190443
# 17     summ_stem_n123 - KNN  summ_stem_n123        KNN   0.097579
# 2        summ_stem_n1 - KNN    summ_stem_n1        KNN   0.095190
# 5    summ_lem_n123 - RanFst   summ_lem_n123     RanFst   2.343647
# 10     summ_lem_n1 - RanFst     summ_lem_n1     RanFst   2.268005
# 7       summ_lem_n123 - KNN   summ_lem_n123        KNN   0.100706
# 12        summ_lem_n1 - KNN     summ_lem_n1        KNN   0.099801
# 9     summ_lem_n123 - DTree   summ_lem_n123      DTree   2.832996
# 4      summ_stem_n1 - DTree    summ_stem_n1      DTree   2.706737
# 19   summ_stem_n123 - DTree  summ_stem_n123      DTree   2.697105
# 14      summ_lem_n1 - DTree     summ_lem_n1      DTree   2.643218
#
#     act_target_pct  accuracy_score  precision_score  recall_score  f1_score  \
# 3             43.8        0.853466         0.814866      0.861373  0.837475
# 18            43.8        0.837553         0.800903      0.837581  0.818832
# 3             43.8        0.837492         0.798833      0.841020  0.819384
# 13            43.8        0.829114         0.791723      0.827909  0.809412
# 8             43.8        0.829013         0.790760      0.829330  0.809586
# 16            43.8        0.803978         0.769465      0.789218  0.779216
# 1             43.8        0.797689         0.761221      0.784496  0.772683
# 6             43.8        0.794897         0.756770      0.784038  0.770163
# 11            43.8        0.790416         0.753779      0.774961  0.764223
# 15            43.8        0.780350         0.778113      0.697855  0.735802
# 0             43.8        0.774704         0.770751      0.691712  0.729096
# 17            43.8        0.774583         0.721792      0.790318  0.754502
# 2             43.8        0.771208         0.726074      0.767580  0.746251
# 5             43.8        0.770002         0.771316      0.675529  0.720252
# 10            43.8        0.766988         0.764950      0.676125  0.717800
# 7             43.8        0.765984         0.710314      0.787063  0.746722
# 12            43.8        0.764758         0.718555      0.761575  0.739440
# 9             43.8        0.719771         0.678999      0.684010  0.681495
# 4             43.8        0.718465         0.681628      0.671129  0.676337
# 19            43.8        0.718445         0.679375      0.677226  0.678298
# 14            43.8        0.717882         0.679573      0.674246  0.676899
#
#        TN    FN    FP     TP
# 3   23687  3024  4269  18790
# 18  23414  3543  4542  18271
# 3   23336  3468  4620  18346
# 13  23205  3754  4751  18060
# 8   23169  3723  4787  18091
# 16  22798  4598  5158  17216
# 1   22588  4701  5368  17113
# 6   22459  4711  5497  17103
# 11  22434  4909  5522  16905
# 15  23615  6591  4341  15223
# 0   23468  6725  4488  15089
# 17  21311  4574  6645  17240
# 2   21639  5070  6317  16744
# 5   23587  7078  4369  14736
# 10  23424  7065  4532  14749
# 7   20954  4645  7002  17169
# 12  21449  5201  6507  16613
# 9   20902  6893  7054  14921
# 4   21118  7174  6838  14640
# 19  20984  7041  6972  14773
# 14  21021  7106  6935  14708

# %% [markdown]
# Display base model, mean response probability model and voting model results ranked by accuracy score, high to low.

# %%
df_all_metrics.sort('accuracy_score',ascending=False)[:30]
# Out:
#                    pair_name       fset_name model_name   duration  \
# 3        Structured - LogReg      Structured     LogReg   0.248161
# 18   summ_stem_n123 - LogReg  summ_stem_n123     LogReg   0.225784
# 3      summ_stem_n1 - LogReg    summ_stem_n1     LogReg   0.234482
# 13      summ_lem_n1 - LogReg     summ_lem_n1     LogReg   0.226267
# 8     summ_lem_n123 - LogReg   summ_lem_n123     LogReg   0.218518
# 17  summ_stem_n123 - Vote 3+  summ_stem_n123    Vote 3+   0.000000
# 12    summ_stem_n1 - Vote 3+    summ_stem_n1    Vote 3+   0.000000
# 7    summ_lem_n123 - Vote 3+   summ_lem_n123    Vote 3+   0.000000
# 2      summ_lem_n1 - Vote 3+     summ_lem_n1    Vote 3+   0.000000
# 16  summ_stem_n123 - Vote 2+  summ_stem_n123    Vote 2+   0.000000
# 11    summ_stem_n1 - Vote 2+    summ_stem_n1    Vote 2+   0.000000
# 18  summ_stem_n123 - Vote 4+  summ_stem_n123    Vote 4+   0.000000
# 16   summ_stem_n123 - AdaBst  summ_stem_n123     AdaBst  17.541474
# 6    summ_lem_n123 - Vote 2+   summ_lem_n123    Vote 2+   0.000000
# 1      summ_lem_n1 - Vote 2+     summ_lem_n1    Vote 2+   0.000000
# 38   summ_stem_n123 - MRP 50  summ_stem_n123     MRP 50   0.000000
# 37   summ_stem_n123 - MRP 45  summ_stem_n123     MRP 45   0.000000
# 13    summ_stem_n1 - Vote 4+    summ_stem_n1    Vote 4+   0.000000
# 27     summ_stem_n1 - MRP 50    summ_stem_n1     MRP 50   0.000000
# 26     summ_stem_n1 - MRP 45    summ_stem_n1     MRP 45   0.000000
# 1      summ_stem_n1 - AdaBst    summ_stem_n1     AdaBst  17.667757
# 8    summ_lem_n123 - Vote 4+   summ_lem_n123    Vote 4+   0.000000
# 39   summ_stem_n123 - MRP 55  summ_stem_n123     MRP 55   0.000000
# 3      summ_lem_n1 - Vote 4+     summ_lem_n1    Vote 4+   0.000000
# 6     summ_lem_n123 - AdaBst   summ_lem_n123     AdaBst  17.612633
# 5       summ_lem_n1 - MRP 50     summ_lem_n1     MRP 50   0.000000
# 4       summ_lem_n1 - MRP 45     summ_lem_n1     MRP 45   0.000000
# 28     summ_stem_n1 - MRP 55    summ_stem_n1     MRP 55   0.000000
# 16    summ_lem_n123 - MRP 50   summ_lem_n123     MRP 50   0.000000
# 36   summ_stem_n123 - MRP 40  summ_stem_n123     MRP 40   0.000000
#
#     act_target_pct  accuracy_score  precision_score  recall_score  f1_score  \
# 3             43.8        0.853466         0.814866      0.861373  0.837475
# 18            43.8        0.837553         0.800903      0.837581  0.818832
# 3             43.8        0.837492         0.798833      0.841020  0.819384
# 13            43.8        0.829114         0.791723      0.827909  0.809412
# 8             43.8        0.829013         0.790760      0.829330  0.809586
# 17            43.8        0.827969         0.794751      0.819015  0.806701
# 12            43.8        0.822925         0.790993      0.810030  0.800399
# 7             43.8        0.816616         0.780847      0.808517  0.794442
# 2             43.8        0.815773         0.784861      0.798570  0.791656
# 16            43.8        0.810549         0.732442      0.894517  0.805407
# 11            43.8        0.809423         0.730733      0.894976  0.804558
# 18            43.8        0.806048         0.840396      0.688182  0.756710
# 16            43.8        0.803978         0.769465      0.789218  0.779216
# 6             43.8        0.802833         0.722876      0.892179  0.798654
# 1             43.8        0.802210         0.724157      0.886357  0.797089
# 38            43.8        0.801226         0.762542      0.793619  0.777770
# 37            43.8        0.800542         0.735228      0.851609  0.789151
# 13            43.8        0.800281         0.843219      0.668653  0.745858
# 27            43.8        0.799719         0.765415      0.783029  0.774122
# 26            43.8        0.798835         0.735870      0.843953  0.786215
# 1             43.8        0.797689         0.761221      0.784496  0.772683
# 8             43.8        0.797267         0.832012      0.673421  0.744363
# 39            43.8        0.795278         0.790407      0.725222  0.756413
# 3             43.8        0.794937         0.834988      0.663198  0.739244
# 6             43.8        0.794897         0.756770      0.784038  0.770163
# 5             43.8        0.794113         0.757812      0.779316  0.768414
# 4             43.8        0.792405         0.728652      0.838682  0.779805
# 28            43.8        0.792204         0.792117      0.713028  0.750495
# 16            43.8        0.791340         0.752285      0.781150  0.766446
# 36            43.8        0.790858         0.705488      0.897497  0.789993
#
#        TN    FN    FP     TP model_type
# 3   23687  3024  4269  18790       base
# 18  23414  3543  4542  18271       base
# 3   23336  3468  4620  18346       base
# 13  23205  3754  4751  18060       base
# 8   23169  3723  4787  18091       base
# 17  23342  3948  4614  17866       vote
# 12  23287  4144  4669  17670       vote
# 7   23006  4177  4950  17637       vote
# 2   23181  4394  4775  17420       vote
# 16  20828  2301  7128  19513       vote
# 11  20762  2291  7194  19523       vote
# 18  25105  6802  2851  15012       vote
# 16  22798  4598  5158  17216       base
# 6   20495  2352  7461  19462       vote
# 1   20591  2479  7365  19335       vote
# 38  22565  4502  5391  17312        mrp
# 37  21266  3237  6690  18577        mrp
# 13  25244  7228  2712  14586       vote
# 27  22721  4733  5235  17081        mrp
# 26  21348  3404  6608  18410        mrp
# 1   22588  4701  5368  17113       base
# 8   24990  7124  2966  14690       vote
# 39  23761  5994  4195  15820        mrp
# 3   25097  7347  2859  14467       vote
# 6   22459  4711  5497  17103       base
# 5   22523  4814  5433  17000        mrp
# 4   21143  3519  6813  18295        mrp
# 28  23874  6260  4082  15554        mrp
# 16  22345  4774  5611  17040        mrp
# 36  19783  2236  8173  19578        mrp

# %% [markdown]
# Plot feature importance for the top 20 features of the Random Forest and Decision Tree classification models.

# %%
df_tree = osha.get_tree_model_info(svd_dict.keys(), clfs, model_dict, col_dict)
osha.plot_tree_importance(svd_dict.keys(), clfs, 20, model_dict, col_dict, fs_dir, save=True)

# %% [markdown]
# Plot feature importance for the top 20 features of the Logistic Regression classification model.

# %%
df_logreg = osha.get_logreg_model_info(svd_dict.keys(), clfs, model_dict, col_dict)
osha.plot_logreg_coef_importance(svd_dict.keys(), clfs, df_logreg, 10, model_dict, col_dict, fs_dir, save=True)

# %% [markdown]
# Plot gains chart for the base classification models.

# %%
osha.plot_gains_charts(df_results, clfs, svd_dict.keys(), 'fset', fs_dir,\
                       save=True, dfs=df_results_struct, dfsn='Best Structured Model')

# %% [markdown]
# Plot precision-recall chart for the base classification models.

# %%
osha.plot_precision_recall_charts(df_results, clfs, svd_dict.keys(), 'fset', fs_dir, save=True)

# %% [markdown]
# Plot mean response probability model and voting model results chart.

# %%
osha.plot_combination_model_chart(df_mrp_metrics, df_voting_metrics, svd_dict.keys(), len(clfs), fs_dir, save=False)

# %% [markdown]
# Load trained base classification model results, compute combination model results and extend results in preparation for subsequent analyses.

# %%
df_base_metrics = df_all_metrics[df_all_metrics.model_type=='base']
df_base_results = df_all_results[df_all_results.model_type=='base']
struct_FN_idx = df_results_struct[(df_results_struct.target_ind==1)&(df_results_struct.target_pred==0)].index
struct_FP_idx = df_results_struct[(df_results_struct.target_ind==0)&(df_results_struct.target_pred==1)].index
df_piv_pred_0_prob = df_base_results.reset_index().pivot('summary_nr','pair_name','pred_0_prob')
df_piv_pred_1_prob = df_base_results.reset_index().pivot('summary_nr','pair_name','pred_1_prob')
df_struct_FN = df_piv_pred_1_prob.ix[struct_FN_idx].sort('Structured - LogReg',ascending=True)
df_struct_FP = df_piv_pred_0_prob.ix[struct_FP_idx].sort('Structured - LogReg',ascending=True)
df_outcome = df_base_results.reset_index().pivot('summary_nr','pair_name','outcome_nbr').\
    join(df_results_struct.pred_1_prob,how='inner')
df_outcome.sort('pred_1_prob',ascending=False,inplace=True)
df_outcome = df_outcome.drop('pred_1_prob',axis=1)

# %% [markdown]
# Plot outcome comparison (TP,FP,FN,TN) for best Structured classification model and all 20 Summary SVD classification models.

# %%
osha.plot_outcome_comparison(df_outcome, fs_dir, figsize=(10, 6), save=True)

# %% [markdown]
# Plot best Structured classification model False Negative cases along with all 20 Summary SVD classification model outcomes.

# %%
osha.plot_best_FN(df_struct_FN, fs_dir, save=True)

# %% [markdown]
# Plot best Structured classification model False Positive cases along with all 20 Summary SVD classification model outcomes.

# %%
osha.plot_best_FP(df_struct_FP, fs_dir, save=True)

# %% [markdown]
# Load the Structured data reference table.

# %%
from IPython.display import HTML
df_struct_ref = pd.read_csv(osha.structured_dir + 'df_struct_ref.csv', index_col='summary_nr')

# %% [markdown]
# Examine best Structured model significant false positive cases where the Summary SVD models were highly confident and accurate.

# %%
df_struct_FP[df_struct_FP['summ_stem_n1 - LogReg'] > 0.9]\
    [['summ_stem_n1 - LogReg','summ_stem_n1 - RanFst','Structured - LogReg']].sort('Structured - LogReg').head()
# Out:
# pair_name   summ_stem_n1 - LogReg  summ_stem_n1 - RanFst  Structured - LogReg
# summary_nr
# 170155774                0.984004                    0.9             0.010324
# 170702419                0.981479                    1.0             0.018435
# 170375091                0.961836                    1.0             0.032592
# 201051695                0.912916                    0.8             0.034454
# 170375067                0.995917                    1.0             0.038631

# %% [markdown]
# Select single case to analyze and view Structured attributes.

# %%
df_struct_ref.ix[170375067]
# Out:
# fatality_ind                                                        0
# sic_desc            Industrial and Commercial Machinery and Comput...
# event_ts                                          1995-03-21 21:10:00
# event_year                                                       1995
# event_month                                                         3
# event_hour                                                         21
# nature_of_inj                                                ASPHYXIA
# part_of_body                                                    CHEST
# src_of_injury                                     ELEC APPARAT/WIRING
# event_type                                                 INHALATION
# evn_factor                                         PINCH POINT ACTION
# hum_factor                             MATER-HANDLG PROCED. INAPPROPR
# occ_code                                      Occupation not reported
# osha_detail_url     https://www.osha.gov/pls/imis/establishment.in...
# weekend_ind                                                         0
# regular_task_ind                                                    1
# Name: 170375067, dtype: object

# %% [markdown]
# Embed case summary from OSHA website.

# %%
HTML('<iframe src=' + df_struct_ref.ix[170375067].ix['osha_detail_url'] + ' width=600 height=1150></iframe>')
# Out:
# <iframe src=https://www.osha.gov/pls/imis/establishment.inspection_detail?id=119705150 width=600 height=1150></iframe>

# %% [markdown]
# Examine best Structured model significant false negative cases where the Summary SVD models were highly confident and accurate.

# %%
df_struct_FN[df_struct_FN['summ_stem_n1 - LogReg'] > 0.9]\
    [['summ_stem_n1 - LogReg','summ_stem_n1 - RanFst','Structured - LogReg']].sort('Structured - LogReg').head()
# Out:
# pair_name   summ_stem_n1 - LogReg  summ_stem_n1 - RanFst  Structured - LogReg
# summary_nr
# 200841021                0.924540                    0.6             0.006773
# 170043756                0.983985                    0.7             0.010203
# 170235147                0.900993                    0.9             0.035684
# 201981313                0.942128                    0.8             0.063521
# 14486997                 0.985945                    1.0             0.107714

# %% [markdown]
# Select single case to analyze and view Structured attributes.

# %%
df_struct_ref.ix[170235147]
# Out:
# fatality_ind                                                        1
# sic_desc                   Lumber and Wood Products, Except Furniture
# event_ts                                          1994-10-04 00:00:00
# event_year                                                       1994
# event_month                                                        10
# event_hour                                                          0
# nature_of_inj                                                FRACTURE
# part_of_body                                               FOOT/ANKLE
# src_of_injury                                                   OTHER
# event_type                                                  STRUCK BY
# evn_factor                             OVERHEAD MOVING/FALLING OBJ AC
# hum_factor                                MISJUDGMENT, HAZ. SITUATION
# occ_code                                      Occupation not reported
# osha_detail_url     https://www.osha.gov/pls/imis/establishment.in...
# weekend_ind                                                         0
# regular_task_ind                                                    1
# Name: 170235147, dtype: object

# %% [markdown]
# Embed case summary from OSHA website.

# %%
HTML('<iframe src=' + df_struct_ref.ix[170235147].ix['osha_detail_url'] + ' width=600 height=1140></iframe>')
# Out:
# <iframe src=https://www.osha.gov/pls/imis/establishment.inspection_detail?id=111260592 width=600 height=1140></iframe>
